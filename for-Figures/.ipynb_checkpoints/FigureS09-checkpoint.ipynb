# %%
import pandas as pd
import glob
import os
import openpyxl
import matplotlib.pyplot as plt

dir_path = "/Users/yukiharuta/Desktop/Python/FCG-excels"
files = glob.glob(f'{dir_path}/*.xlsx')
files.sort()

X, Y = [], []

for file in files:
   
    if not 'FALSE' in file:
        try:
            # glab the data
            df = pd.read_excel(file, sheet_name ='Data')
            
            # Read the second and third sheet
            wb = openpyxl.load_workbook(file)
            ws_P = wb["Parameters"]
            ws_I = wb["Information"]

            # ID
            ID = os.path.basename(file)[:-5]

            # SV
            SV = ws_P['I6'].value # Set growth rate (mm/h)

            # sPV calculation
            Smth_G = df['Smth_G (mm/h)'].to_list()
            last_G = Smth_G[-2169:] #cut the last 3 hour
            sPV = sum(last_G)/len(last_G) # average growth rate at the last 3 hours (mm/h)

            # Error
            gap = sPV - SV

            # Predicted Evaporation
            infusion = df['Inf-rate (mL/h)'].to_list()[-1]
            e_t = df['e(t)'].to_list()[-1]
            dedt = df['de(t)/dt'].to_list()[-1]

            Kp = ws_P['I8'].value
            Kd = ws_P['I10'].value
            
            try:
                int_e = df['int e'].to_list()[-1]
                Ki = ws_P['I9'].value
                Est_evap = infusion - (Kp*e_t + Ki*int_e + Kd*dedt) # mL/h
            except:
                Est_evap = infusion - (Kp*e_t + Kd*dedt) # mL/h
                
            Est_evap = Est_evap * 0.944 # g/h
            
            # Actual evap
            Act_evap = ws_I['I6'].value
            
            # Evaporation error
            Error_evap = Act_evap - Est_evap
            
            X.append(Error_evap)
            Y.append(gap)
            
            print(f'ID: {ID}, sPV-SV: {gap:.3f}, Act-Est: {Error_evap:.2f}')
            
        except Exception as e:
            print(e)

plt.plot(X,Y)
# Out:
# ID: 230118_A, sPV-SV: 0.068, Act-Est: 0.32
# ID: 230119_A, sPV-SV: -0.001, Act-Est: 0.25
# ID: 230121_A, sPV-SV: 0.039, Act-Est: 0.20
# ID: 230124_A, sPV-SV: 0.013, Act-Est: 0.05
# ID: 230128_A, sPV-SV: 0.027, Act-Est: 0.09
# ID: 230130_A, sPV-SV: 0.276, Act-Est: 0.36
# ID: 230131_A, sPV-SV: 0.045, Act-Est: 0.04
# ID: 230202_A, sPV-SV: 0.009, Act-Est: 0.06
# ID: 230204_A, sPV-SV: 0.028, Act-Est: 0.60
# ID: 230205_A, sPV-SV: -0.018, Act-Est: 0.02
# ID: 230214_A, sPV-SV: 0.039, Act-Est: 0.13
# ID: 230218_A, sPV-SV: -0.028, Act-Est: 0.13
# ID: 230220_A, sPV-SV: -0.009, Act-Est: 0.59
# ID: 230223_A, sPV-SV: 0.074, Act-Est: 0.25
# ID: 230308_A, sPV-SV: 0.052, Act-Est: 0.29
# ID: 230323_A, sPV-SV: 0.134, Act-Est: 0.50
# ID: 230325_A, sPV-SV: 0.123, Act-Est: 0.43
# ID: 230326_A, sPV-SV: 0.076, Act-Est: 0.28
# ID: 230328_A, sPV-SV: 0.143, Act-Est: 0.58
# ID: 230329_A, sPV-SV: 0.145, Act-Est: 0.58
# ID: 230330_A, sPV-SV: 0.081, Act-Est: 0.20
# unsupported operand type(s) for -: 'NoneType' and 'float'
# ID: 230426_A, sPV-SV: 0.044, Act-Est: 0.04
# ID: 230427_A, sPV-SV: 0.048, Act-Est: 0.35
# ID: 230429_A, sPV-SV: -0.000, Act-Est: 0.00
# ID: 230501_A, sPV-SV: -0.051, Act-Est: -0.02
# ID: 230505_A, sPV-SV: 0.119, Act-Est: 0.11
# ID: 230509_A, sPV-SV: -0.065, Act-Est: -0.11
# ID: 230512_A, sPV-SV: 0.041, Act-Est: 0.36
# ID: 230517_A, sPV-SV: -0.076, Act-Est: -0.28
# ID: 230528_A, sPV-SV: -0.035, Act-Est: -0.18
# ID: 230601_A, sPV-SV: 0.117, Act-Est: 0.71
# ID: 230607_A, sPV-SV: -0.028, Act-Est: -0.30
# ID: 230609_A, sPV-SV: -0.150, Act-Est: -0.95
# ID: 230613_A, sPV-SV: -0.090, Act-Est: -0.57
# unsupported operand type(s) for -: 'float' and 'NoneType'
# unsupported operand type(s) for -: 'float' and 'NoneType'
# ID: 230624_A, sPV-SV: 0.014, Act-Est: 0.07
# ID: 230703_A, sPV-SV: 0.009, Act-Est: 0.05
# ID: 230705_A, sPV-SV: -0.001, Act-Est: -0.06
# ID: 230710_A, sPV-SV: 0.050, Act-Est: -0.03
# ID: 230717_A, sPV-SV: -0.024, Act-Est: -0.22
# ID: 230724_A, sPV-SV: 0.271, Act-Est: 0.22
# unsupported operand type(s) for -: 'float' and 'NoneType'
# ID: 230726_A, sPV-SV: -0.083, Act-Est: -0.22
# unsupported operand type(s) for -: 'float' and 'NoneType'
# ID: 230802_A, sPV-SV: 0.152, Act-Est: 0.53
# ID: 230814_A, sPV-SV: 0.033, Act-Est: 0.14
# ID: 230816_A, sPV-SV: 0.026, Act-Est: -0.02
# ID: 230829_A, sPV-SV: -0.018, Act-Est: -0.48
# ID: 230907_D, sPV-SV: -0.039, Act-Est: -0.16
# ID: 230912_A, sPV-SV: 0.009, Act-Est: -0.30
# ID: 230918_A, sPV-SV: -0.016, Act-Est: 0.09
# ID: 230920_A, sPV-SV: -0.007, Act-Est: -0.06
# ID: 230921_D, sPV-SV: 0.019, Act-Est: 0.06
# ID: 230925_C, sPV-SV: 0.690, Act-Est: 2.09
# ID: 230925_D, sPV-SV: -0.018, Act-Est: -0.33
# ID: 230927_B, sPV-SV: -0.054, Act-Est: -0.23
# ID: 231006_A, sPV-SV: -0.015, Act-Est: 0.12
# ID: 231006_AY3, sPV-SV: -0.002, Act-Est: -0.16
# ID: 231006_AY4, sPV-SV: -0.022, Act-Est: -0.24
# ID: 231010_AY2, sPV-SV: 0.008, Act-Est: -0.05
# ID: 231010_AY4, sPV-SV: -0.016, Act-Est: -0.23
# ID: 231013_AY2, sPV-SV: 0.001, Act-Est: -0.07
# ID: 231013_AY3, sPV-SV: -0.011, Act-Est: -0.28
# ID: 231018_AY1, sPV-SV: 0.073, Act-Est: -0.46
# ID: 231018_AY2, sPV-SV: -0.029, Act-Est: -0.63
# ID: 231018_AY4, sPV-SV: -0.004, Act-Est: 0.11
# Excel file format cannot be determined, you must specify an engine manually.

# %%
import numpy as np
from sklearn.metrics import r2_score

# plot
plt.rcParams["font.size"] = 17
fig = plt.figure(figsize=(6,5))
color = "#474D6B" # dark blue

plt.scatter(X,Y,color=f'{color}80', edgecolor = color)
plt.xlabel('Estimation error (g/h)')
plt.ylabel('sPV - SV (mm/h)')
plt.xlim(-1,1)
plt.ylim(-0.2,0.3)

slope, intercept = np.polyfit(X,Y,1)
x_fit = [-1,1]
y_fit = [n*slope + intercept for n in x_fit]

plt.plot(x_fit, y_fit, linestyle = 'dashed', color = color)
print(slope, intercept)

y_fit = [n*slope + intercept for n in X]
print(r2_score(Y, y_fit))
print(len(Y))


# plt.text(-0.85,0.2, '$\it{σ}_{xy}/\it{σ}_{x}\it{σ}_{y} = 0.82$', ha='left', va='bottom',color=color,fontsize=17)

import numpy as np
from scipy.stats import pearsonr

# 2つのリストを作成する（例としてランダムなデータを使用）
list1 = X
list2 = Y

# リストをNumPy配列に変換
array1 = np.array(list1)
array2 = np.array(list2)

# 2つのリストの相関係数を計算
correlation, _ = pearsonr(array1, array2)

print("相関係数:", correlation)

figsavepath = "/Users/yukiharuta/Desktop/Temp-Data/MAPbBr3-Paper/00_Paper-work/Plots"
plt.savefig(f'{figsavepath}/evap-gap.svg', dpi=1200, bbox_inches='tight', transparent=True)
# Out:
# 0.22282464689230203 0.019102799781003103
# 0.6689068242870795
# 63
# 相関係数: 0.8178672412360576
