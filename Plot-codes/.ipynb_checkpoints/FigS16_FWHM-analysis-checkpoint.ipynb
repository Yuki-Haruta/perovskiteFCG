# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

save_option = False
figsavepath = "../Figures/FigureS9.svg"

path = "../Data/01_SUMMARY.xlsx"
df = pd.read_excel(path)

S = df['SV'].to_list()
X = df['PV'].to_list()
Y = df['FWHM'].to_list()
R = df['R2'].to_list()
L = df['L_end'].to_list()

# remove Failed experiment
False_check = df['FALSE'].to_list()
False_indices = [i for i, x in enumerate(False_check) if x == 1]
for index in sorted(False_indices, reverse=True):
    del S[index]
    del X[index]
    del Y[index]
    del R[index]
    del L[index]

# remove nan
nan_indices = [i for i, x in enumerate(Y) if isinstance(x, float) and math.isnan(x)]
for index in sorted(nan_indices, reverse=True):
    del S[index]
    del X[index]
    del Y[index]
    del R[index]
    del L[index]
    
# remove fitfail
str_indices = [i for i, x in enumerate(Y) if not isinstance(x, float)]
for index in sorted(str_indices, reverse=True):
    del S[index]
    del X[index]
    del Y[index]
    del R[index]
    del L[index]
    
# remove bad fitting
R2_indices = [i for i, x in enumerate(R) if x < 0.97]
for index in sorted(R2_indices, reverse=True):
    del S[index]
    del X[index]
    del Y[index]
    del R[index]
    del L[index]

# remove too small crystals
L_indices = [i for i, x in enumerate(L) if x < 4]
for index in sorted(L_indices, reverse=True):
    del S[index]
    del X[index]
    del Y[index]
    del R[index]
    del L[index]
    
threshold = 0.3
Y1, Y2 = [], []
for x, y in zip(X,Y):
    if x < threshold:
        Y1.append(y)
    else:
        Y2.append(y)
        
plt.scatter(X,Y)
# plt.xlim(0,1)
plt.xlabel('sPV (mm/h)')
plt.ylabel('FWHM (arcsec)')
plt.show()

plt.scatter(X,Y)
plt.xlim(0,1)
plt.xlabel('sPV (mm/h)')
plt.ylabel('FWHM (arcsec)')
plt.show()

plt.scatter(S,Y)
plt.xlim(0,1)
plt.xlabel('SV (mm/h)')
plt.ylabel('FWHM (arcsec)')
plt.show()

mean, width = 1, 0.2
X1 = np.random.uniform(mean-width, mean+width, len(Y1))
X1 -= np.mean(X1)
X1 += mean # mean value

mean, width = 2, 0.2
X2 = np.random.uniform(mean-width, mean+width, len(Y2))
X2 -= np.mean(X2)
X2 += mean # mean value

plt.scatter(X1,Y1,ec='blue',c='white')
plt.scatter(X2,Y2,ec='orange',c='white')
plt.xticks([])
plt.xlim(0,3)
plt.ylabel('FWHM (arcsec)')
plt.show()
print(len(Y1),len(Y2))

def print_statistics(lst):
    q_1 = np.percentile(lst, 25)
    q_2 = np.percentile(lst, 50)
    q_3 = np.percentile(lst, 75)
    print(f'Q2: {q_2:.2f}, Q3-Q1: {q_3-q_1:.2f}')

print_statistics(Y1)
print_statistics(Y2)
print(f'Threshold: {threshold} mm/h')
# Out:
# 35 16
# Q2: 19.63, Q3-Q1: 6.70
# Q2: 26.95, Q3-Q1: 8.70
# Threshold: 0.3 mm/h

# %%
import numpy as np
import scipy.stats as stats

for data in [Y1, Y2]:
    # 標本の平均と標準偏差を計算
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1) # 標本標準偏差 (ddof=1 で不偏推定量とする)

    # 標本サイズ
    n = len(data)

    # 母集団の平均値の95%信頼区間を計算
    confidence_level = 0.90
    alpha = 1 - confidence_level
    t_critical = stats.t.ppf(1 - alpha/2, df=n-1) # t分布の上側確率

    # 信頼区間の幅
    margin_of_error = t_critical * (sample_std / np.sqrt(n))

    # 信頼区間
    confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

    print(sample_mean, sample_std**2, confidence_interval)
# Out:
# 23.445403407308458 116.70402320361246 (20.604511904847797, 26.28629490976912)
# 30.318789728523953 285.9223088212033 (24.264448223109955, 36.373131233937954)

# %%
bin_width = 2
bin_edges = np.arange(start=14, stop=48 + bin_width, step=bin_width)
color1 = "#474D6B" # dark blue

plt.hist(Y1,color=f"{color1}50", ec=color1, bins = bin_edges)
plt.xlim(10,50)
plt.ylim(0,15)
# Out:
# (0.0, 15.0)

# %%
bin_width = 2
bin_edges = np.arange(start=14, stop=48 + bin_width, step=bin_width)
color1 = "#474D6B" # dark blue

plt.hist(Y2,color=f"{color1}50", ec=color1, bins = bin_edges)
plt.xlim(10,50)
plt.ylim(0,15)
# Out:
# (0.0, 15.0)

# %%
Y_02 = []
for x, y in zip(S,Y):
    if x <= 0.2:
        Y_02.append(y)
        
bin_width = 2
bin_edges = np.arange(start=14, stop=48 + bin_width, step=bin_width)
color1 = "#474D6B" # dark blue

print(f'N: {len(Y_02)}')
plt.hist(Y_02,color=f"{color1}50", ec=color1, bins = bin_edges)
plt.xlim(10,50)
plt.ylim(0,12)
# Out:
# N: 37
# (0.0, 12.0)

# %%
Y_02 = []
for x, y in zip(S,Y):
    if x > 0.2:
        Y_02.append(y)
        
bin_width = 2
bin_edges = np.arange(start=14, stop=48 + bin_width, step=bin_width)
color1 = "#474D6B" # dark blue

print(f'N: {len(Y_02)}')
plt.hist(Y_02,color=f"{color1}50", ec=color1, bins = bin_edges)
plt.xlim(10,50)
plt.ylim(0,12)
# Out:
# N: 24
# (0.0, 12.0)

# %%
len(bin_edges)
# Out:
# 18

# %%
bin_width = 1
bin_edges = np.arange(start=min(Y1), stop=max(Y1) + bin_width, step=bin_width)

bins = []
for i in range(len(bin_edges)-1):
    bins.append([])
    
X1 = []
for y in Y1:
    for i in range(len(bin_edges)-1):
        if bin_edges[i] <= y < bin_edges[i+1]:
            bins[i].append(1)
            X1.append(len(bins[i])*0.1+1)

bin_width = 1
bin_edges = np.arange(start=min(Y2), stop=max(Y2) + bin_width, step=bin_width)

bins = []
for i in range(len(bin_edges)-1):
    bins.append([])
    
X2 = []
for y in Y2:
    for i in range(len(bin_edges)-1):
        if bin_edges[i] <= y < bin_edges[i+1]:
            bins[i].append(1)
            X2.append(len(bins[i])*0.1+2.5)
            
plt.scatter(X1,Y1,ec='blue',c='white')
plt.scatter(X2,Y2,ec='orange',c='white')
plt.xticks([])
plt.xlim(0,4)
plt.ylabel('FWHM (arcsec)')
plt.show()
print(len(Y1),len(Y2))
# Out:
# 41 23
